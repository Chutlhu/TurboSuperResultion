# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from argparse import Namespace
from pathlib import Path
import torch
from pytorch_lightning.trainer import Trainer, seed_everything
from pytorch_lightning.callbacks import EarlyStopping, ModelCheckpoint

from turboflow.dataloaders import TurboFlowDataModule
from turboflow.evaluation import compute_all_metrics

from turboflow.utils import phy_utils as phy
from turboflow.utils import dsp_utils as dsp
from turboflow.utils import torch_utils as tch
from turboflow.utils import file_utils as fle
from turboflow.utils import viz_utils as viz

import matplotlib.pyplot as plt

import glob

import numpy as np
import pandas as pd
import yaml

import seaborn as sns

from natsort import natsorted

# %%
# load dataset
data_dir = Path('/','home','dicarlo_d','Documents','Datasets','Turb2D.hdf5')
dm = TurboFlowDataModule(dataset='Turb2D', 
                         data_dir=data_dir,
                         batch_size=100000,
                         time_idx=0,
                         train_downsampling=8,
                         val_downsampling=4,
                         test_downsampling=1,
                         num_workers=1)
dm.setup()


X_lr, y_lr = dm.train_dataset[:]
img_shape_lr = dm.train_dataset.img_shape[:2]
shape_lr = dm.train_dataset.img_shape
L = shape_lr[0]
N_lr = X_lr.shape[0]
print(N_lr, L)

X_mr, y_mr = dm.val_dataset[:]
img_shape_mr = dm.val_dataset.img_shape[:2]
shape_mr = dm.val_dataset.img_shape
M = shape_mr[0]
N_mr = X_mr.shape[0]
print(N_mr, M)

X_hr, y_hr = dm.test_dataset[:]
img_shape_hr = dm.test_dataset.img_shape[:2]
shape_hr = dm.test_dataset.img_shape
H = shape_hr[0]
N_hr = X_hr.shape[0]
print(N_hr, H)

dsets_dict = {}

dsets = {
    'train' : dm.train_dataset,
    'val' : dm.val_dataset,
    'test' : dm.test_dataset
}

for stage in dsets.keys():
    tmp = {}
    
    dset = dsets[stage]
    X, y = dset[:]
    img_shape = dset.img_shape[:2]
    shape = dset.img_shape
    R = shape[0]
    
    print(stage, X.shape, y.shape, R)
    
    tmp['X'] = X
    tmp['y'] = y
    tmp['R'] = R
    tmp['img_shape'] = img_shape
    
    dsets_dict[stage] = tmp
# Out:
# 1024 32
# 4096 64
# 65536 256
# train torch.Size([1024, 2]) torch.Size([1024, 2]) 32
# val torch.Size([4096, 2]) torch.Size([4096, 2]) 64
# test torch.Size([65536, 2]) torch.Size([65536, 2]) 256

# %%
figsize = (6,6)
region=(0.05, 0.35, 0.45, 0.75)

Xlr = dsets_dict['train']['X']
Ulr = dsets_dict['train']['y']
L = dsets_dict['train']['R']
Xhr = dsets_dict['test']['X']
Uhr = dsets_dict['test']['y']
H = dsets_dict['test']['R']


viz.plot_lr_hr_inset(Uhr, Uhr, H, H, figsize=figsize, title='GroundTruth RFF', 
                     region = region,
                     only_u=True)
plt.show()

viz.plot_velocity_field(Xhr, Uhr, H, Xhr, Uhr, H,
                        title=None,
                        figsize=figsize,
                        region = region,
                        scale_lr=10, step_lr=4,
                        scale_hr=5, step_hr=3)
plt.tight_layout()
plt.show()

# %%
results_dir = Path('..','recipes','turbo2D','single_images','results')
files = glob.glob(str(results_dir.resolve()) + '/*.pkl')
files.sort(key=os.path.getmtime)
# results_paths = natsorted(list(glob('*')))
results_paths = files

# %%
df = pd.DataFrame()

c = 0
for path in results_paths:
    path = Path(path)
    results_dict = fle.load_obj(path)
    
    df.at[c, 'name'] = results_dict['hparams']['name']
    df.at[c, 'version'] = results_dict['pl_version']
    df.at[c, 'success'] = results_dict['success']
    
    for field in ['mlp_layers_num','rff_num','lam_sdiv', 'do_divfree', 'lam_curl','lam_grads', 'lam_sfn', 'lam_weight']:
        df.at[c, field] = results_dict['hparams'][field]
    
    df.at[c, 'rec'] = results_dict['test_metrics'][0]['test/metrics/reconstruction']
    df.at[c, 'spc'] = results_dict['test_metrics'][0]['test/metrics/log_err_specturm']
    df.at[c, 'ang'] = results_dict['test_metrics'][0]['test/metrics/angular_degree']
    
    df.at[c, 'model_path'] = results_dict['path_to_best_model']
    
    c += 1
    
df.to_csv(results_dir / Path('../results.csv'))
df.sort_values('ang')
# Out:
#                                                   name     version success  \
# 107  RFFMLP_run:666-ds:4-mlp:10-rff_num:512-df:true...   version_9    True
# 103  RFFMLP_run:420-ds:4-mlp:10-rff_num:512-df:true...   version_5    True
# 110  RFFMLP_run:333-ds:4-mlp:10-rff_num:512-df:-lsd...   version_1    True
# 99   RFFMLP_run:333-ds:4-mlp:10-rff_num:512-df:true...   version_1    True
# 109  RFFMLP_run:666-ds:8-mlp:10-rff_num:512-df:true...  version_11    True
# ..                                                 ...         ...     ...
# 22   RFFMLP_run:8-ds:4-mlp:3-rff_num:0-df:true-lsdv...  version_23    True
# 68   RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_69    True
# 56   RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_57    True
# 41   RFFMLP_run:8-ds:4-mlp:3-rff_num:64-df:true-lsd...  version_42    True
# 62   RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_63    True
#
#      mlp_layers_num  rff_num  lam_sdiv do_divfree      lam_curl     lam_grads  \
# 107            10.0    512.0   0.00000       True  1.000000e-08  1.000000e-05
# 103            10.0    512.0   0.00000       True  1.000000e-08  1.000000e-05
# 110            10.0    512.0   0.00100       True  1.000000e-08  1.000000e-05
# 99             10.0    512.0   0.00000       True  1.000000e-08  1.000000e-05
# 109            10.0    512.0   0.00000       True  1.000000e-08  1.000000e-05
# ..              ...      ...       ...        ...           ...           ...
# 22              3.0      0.0   0.00001       True  1.000000e-08  1.000000e-08
# 68              3.0    256.0   0.00100       True  1.000000e-05  1.000000e-08
# 56              3.0    256.0   0.00000       True  1.000000e-05  0.000000e+00
# 41              3.0     64.0   0.00100       True  1.000000e-05  1.000000e-08
# 62              3.0    256.0   0.00000       True  1.000000e-05  1.000000e-05
#
#      lam_sfn  lam_weight       rec        spc        ang  \
# 107      0.0      0.0001  0.000831  47.555229   1.263146
# 103      0.0      0.0001  0.000963  71.547112   1.306746
# 110      0.0      0.0001  0.000985  67.549637   1.332604
# 99       0.0      0.0001  0.000969  81.163902   1.340847
# 109      0.0      0.0001  0.002489  91.561577   1.840463
# ..       ...         ...       ...        ...        ...
# 22       0.0      0.0001  0.093427  47.406933  14.884026
# 68       0.0      0.0001  0.094595  59.492352  14.892103
# 56       0.0      0.0001  0.095303  76.624596  14.952669
# 41       0.0      0.0001  0.095938  65.364334  15.011108
# 62       0.0      0.0001  0.096483  63.900524  15.049736
#
#                                             model_path
# 107  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 103  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 110  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 99   /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 109  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# ..                                                 ...
# 22   /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 68   /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 56   /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 41   /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 62   /home/dicarlo_d/Documents/Code/TurboSuperResul...
#
# [111 rows x 15 columns]

# %%
# best soft
curr_df = df.loc[
                (df['do_divfree'] == True) &
#                 (df['lam_sdiv'] == 0) &
                (df['lam_grads'] > 0) &
                (df['lam_curl'] > 0) &
                (df['lam_sfn'] > 0)
]
curr_df.sort_values('ang')

# 81, 48, 107,
# Out:
# Empty DataFrame
# Columns: [name, version, success, mlp_layers_num, rff_num, lam_sdiv, do_divfree, lam_curl, lam_grads, lam_sfn, lam_weight, rec, spc, ang, model_path]
# Index: []

# %%
Xlr = dsets_dict['test']['X']
Ulr = dsets_dict['test']['y']
L = dsets_dict['test']['R']
Xhr = dsets_dict['test']['X']
Uhr = dsets_dict['test']['y']
H = dsets_dict['test']['R']

curr_df = df

for r, row in curr_df.iterrows():    
    
    if r not in [81, 48, 107]:
        continue
    
    model_path = row['model_path']
    rff_num = row['rff_num']
    do_divfree = row['do_divfree']
    lam_grads = row['lam_grads']
    lam_curl = row['lam_curl']
    
    hc_or_sc = 'Hard' if do_divfree else 'Soft'
    title = r'%s $\lambda$ = %.1E $\lambda$ = %.1E' % (hc_or_sc, lam_grads, lam_curl)
    print(title)
    
    from turboflow.models.phyrff_hard import plDivFreeRFFNet
    model = plDivFreeRFFNet.load_from_checkpoint(model_path)
    
    Uhr = model(X_hr)[0]
    Uhr = Uhr.detach().cpu().numpy()

    from turboflow.models.phyrff_hard import plDivFreeRFFNet
    model = plDivFreeRFFNet.load_from_checkpoint(model_path)

    viz.plot_lr_hr_inset(Uhr, Uhr, H, H, figsize=figsize, title=title, 
                         region = region,
                         only_u=True)
    plt.show()

    viz.plot_velocity_field(Xhr, Uhr, L, Xhr, Uhr, H,
                            title=title,
                            figsize=figsize,
                            region = region,
                            scale_lr=10, step_lr=4,
                            scale_hr=5, step_hr=3)
    plt.tight_layout()
    plt.show()
# Out:
# Hard $\lambda$ = 1.0E-08 $\lambda$ = 0.0E+00
# Hard $\lambda$ = 0.0E+00 $\lambda$ = 0.0E+00
# Hard $\lambda$ = 1.0E-05 $\lambda$ = 1.0E-08

# %%
curr_df = df.loc[
                (df['lam_sdiv'] == 0) &
                (df['lam_grads'] == 0) &
                (df['lam_curl'] == 0) &
                (df['lam_sfn'] == 0)
]

plt.figure(figsize=(10,5))
plt.subplot(131)
sns.barplot(x='rff_num', y='ang',data=curr_df)
plt.subplot(132)
sns.barplot(x='rff_num', y='rec',data=curr_df)
plt.show()

print(curr_df.index)

spec_gt = phy.energy_spectrum(y_hr.view(H,H,2).permute(2,0,1))[0]
plt.figure(figsize=(10,5))
plt.loglog(spec_gt.detach(), 'k--')

for r, row in curr_df.iterrows():    
    
    model_path = row['model_path']
    rff_num = row['rff_num']
    
    from turboflow.models.phyrff_hard import plDivFreeRFFNet
    model = plDivFreeRFFNet.load_from_checkpoint(model_path)
    
    y_hat = model(X_hr)[0]
    
    spec = phy.energy_spectrum(y_hat.view(H,H,2).permute(2,0,1))[0]
    plt.loglog(spec.detach().cpu().numpy(), label=f'{rff_num}')

    
plt.legend()
plt.show()
# Out:
# Int64Index([57, 67, 75, 83], dtype='int64')

# %%
curr_df = df.loc[
                (df['lam_grads'] == 0) &
                (df['lam_curl'] == 0) &
                (df['lam_sfn'] == 0)
]

plt.figure(figsize=(10,5))
plt.subplot(131)
sns.barplot(x='rff_num', y='ang',data=curr_df)
plt.subplot(132)
sns.barplot(x='rff_num', y='rec',data=curr_df)
plt.show()

print(curr_df.index)

spec_gt = phy.energy_spectrum(y_hr.view(H,H,2).permute(2,0,1))[0]
plt.figure(figsize=(10,5))
plt.loglog(spec_gt.detach(), 'k--')

for r, row in curr_df.iterrows():    
    
    model_path = row['model_path']
    rff_num = row['rff_num']
    lam_sdiv = row['lam_sdiv']
    
    from turboflow.models.phyrff_hard import plDivFreeRFFNet
    model = plDivFreeRFFNet.load_from_checkpoint(model_path)
    
    y_hat = model(X_hr)[0]
    
    spec = phy.energy_spectrum(y_hat.view(H,H,2).permute(2,0,1))[0]
    plt.loglog(spec.detach().cpu().numpy(), label=f'{rff_num}_{lam_sdiv}')

    
plt.legend()
plt.show()
# Out:
# Int64Index([13, 18, 21, 57, 67, 69, 73, 75, 83, 88, 90], dtype='int64')

# %%
curr_df = df.loc[
                (df['rff_num'] >= 256) &
                (df['lam_curl'] == 0) &
                (df['lam_sfn'] == 0)
]

plt.figure(figsize=(10,5))
plt.subplot(131)
sns.barplot(x='rff_num', y='ang',data=curr_df)
plt.subplot(132)
sns.barplot(x='rff_num', y='rec',data=curr_df)
plt.show()

print(curr_df.index)
curr_df
# Out:
# Int64Index([9, 13, 19, 25, 27, 42, 43, 48, 53, 57, 66, 69, 75, 87, 88], dtype='int64')
#                                                  name     version success  \
# 9   RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_70    True
# 13  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_64    True
# 19  RFFMLP_run:8-ds:4-mlp:3-rff_num:512-df:true-ls...  version_94    True
# 25  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_58    True
# 27  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_61    True
# 42  RFFMLP_run:8-ds:4-mlp:3-rff_num:512-df:true-ls...  version_97    True
# 43  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_79    True
# 48  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_76    True
# 53  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_67    True
# 57  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_55    True
# 66  RFFMLP_run:8-ds:4-mlp:3-rff_num:512-df:true-ls...  version_85    True
# 69  RFFMLP_run:8-ds:4-mlp:3-rff_num:256-df:true-ls...  version_73    True
# 75  RFFMLP_run:8-ds:4-mlp:3-rff_num:512-df:true-ls...  version_82    True
# 87  RFFMLP_run:8-ds:4-mlp:3-rff_num:512-df:true-ls...  version_88    True
# 88  RFFMLP_run:8-ds:4-mlp:3-rff_num:512-df:true-ls...  version_91    True
#
#     mlp_layers_num  rff_num  lam_sdiv  lam_curl     lam_grads  lam_sfn  \
# 9              3.0    256.0   0.00100       0.0  1.000000e-05      0.0
# 13             3.0    256.0   0.00100       0.0  0.000000e+00      0.0
# 19             3.0    512.0   0.00100       0.0  1.000000e-08      0.0
# 25             3.0    256.0   0.00000       0.0  1.000000e-08      0.0
# 27             3.0    256.0   0.00000       0.0  1.000000e-05      0.0
# 42             3.0    512.0   0.00100       0.0  1.000000e-05      0.0
# 43             3.0    256.0   0.00001       0.0  1.000000e-05      0.0
# 48             3.0    256.0   0.00001       0.0  1.000000e-08      0.0
# 53             3.0    256.0   0.00100       0.0  1.000000e-08      0.0
# 57             3.0    256.0   0.00000       0.0  0.000000e+00      0.0
# 66             3.0    512.0   0.00000       0.0  1.000000e-08      0.0
# 69             3.0    256.0   0.00001       0.0  0.000000e+00      0.0
# 75             3.0    512.0   0.00000       0.0  0.000000e+00      0.0
# 87             3.0    512.0   0.00000       0.0  1.000000e-05      0.0
# 88             3.0    512.0   0.00100       0.0  0.000000e+00      0.0
#
#     lam_weight       rec         spc       ang  \
# 9       0.0001  0.029456  128.751617  7.570065
# 13      0.0001  0.026558  120.827332  7.345861
# 19      0.0001  0.012538  121.164856  4.997313
# 25      0.0001  0.035819  126.742897  8.469627
# 27      0.0001  0.019019  126.797447  6.260316
# 42      0.0001  0.012428  121.716782  4.986285
# 43      0.0001  0.012979  121.415939  5.100121
# 48      0.0001  0.030023  120.947441  7.732529
# 53      0.0001  0.021857  123.832436  6.753746
# 57      0.0001  0.019919  122.591080  6.406679
# 66      0.0001  0.023931  119.717873  6.778911
# 69      0.0001  0.018111  116.315018  6.005716
# 75      0.0001  0.013778  117.188614  5.271949
# 87      0.0001  0.015172  127.039589  5.526896
# 88      0.0001  0.014601  114.481232  5.360553
#
#                                            model_path
# 9   /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 13  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 19  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 25  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 27  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 42  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 43  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 48  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 53  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 57  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 66  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 69  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 75  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 87  /home/dicarlo_d/Documents/Code/TurboSuperResul...
# 88  /home/dicarlo_d/Documents/Code/TurboSuperResul...

# %%
spec_gt = phy.energy_spectrum(y_hr.view(H,H,2).permute(2,0,1))[0]
plt.figure(figsize=(10,5))
plt.loglog(spec_gt.detach(), 'k--')

for r, row in curr_df.iterrows():    
    
    model_path = row['model_path']
    rff_num = row['rff_num']
    lam_sdiv = row['lam_sdiv']
    
    from turboflow.models.phyrff_hard import plDivFreeRFFNet
    model = plDivFreeRFFNet.load_from_checkpoint(model_path)
    
    y_hat = model(X_hr)[0]
    
    spec = phy.energy_spectrum(y_hat.view(H,H,2).permute(2,0,1))[0]
    plt.loglog(spec.detach().cpu().numpy(), label=f'{rff_num}_{lam_sdiv}')

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1558050/1657290149.py in <module>
#      14     y_hat = model(X_hr)[0]
#      15
# ---> 16     spec = phy.energy_spectrum(y_hat.view(H,H,2).permute(2,0,1))[0]
#      17     plt.loglog(spec.detach().cpu().numpy(), label=f'{rff_num}_{lam_sdiv}')
#      18
#
# ~/Documents/Code/TurboSuperResultion/turboflow/utils/phy_utils.py in energy_spectrum(uv)
#     194             # EK_U_avsphr[wn[i,j]] = EK_U_avsphr[wn[i,j]] + Ek[i,j]
#     195             wn =  int(np.round(np.sqrt((i-cx)**2+(j-cy)**2)))
# --> 196             EK_U_avsphr[wn] = EK_U_avsphr[wn] + Ek[i,j]
#     197
#     198     spec = EK_U_avsphr
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='rff_num', y='ang', hue='lam_grads', data=df, size='lam_sdiv')
# Out:
# <AxesSubplot:xlabel='rff_num', ylabel='ang'>

# %%
spec_gt = phy.energy_spectrum(y_hr.view(H,H,2).permute(2,0,1))[0]
plt.figure(figsize=(10,5))
plt.loglog(spec_gt.detach(), 'k--')

for r, row in df.iterrows():    
    
    if r not in [8, 23, 70, 42, 19, 79]:
        continue
    
    model_path = row['model_path']
    rff_num = row['rff_num']
    lam_sdiv = row['lam_sdiv']
    
    from turboflow.models.phyrff_hard import plDivFreeRFFNet
    model = plDivFreeRFFNet.load_from_checkpoint(model_path)
    
    y_hat = model(X_hr)[0]
    
    spec = phy.energy_spectrum(y_hat.view(H,H,2).permute(2,0,1))[0]
    plt.loglog(spec.detach().cpu().numpy(), label=f'{rff_num}_{lam_sdiv}')

plt.tight_layout()
plt.legend()
plt.show()
